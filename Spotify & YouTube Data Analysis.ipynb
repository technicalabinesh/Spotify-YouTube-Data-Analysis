# %% [markdown]
# # Sales Data Analysis with Python
#
# ### (A part of Big Data Analysis)

# %% [markdown]
# -------------

# %% [markdown]
# ## Restaurant Sales Dataset
# ***
# Here,
#
# We have the sales data of a restaurant company from different cities (countries).
#
# This data is available in Excel file format. We are going to analyze and visualize this data.

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# ###### Get the Data Analysis Course Notes and all Projects Source Codes -
#
# https://datasciencelovers.graphy.com/products/Python---Data-Analysis-Course-Notes-675d8784ceba3134be0f61fc?dgps_s=dsh&dgps_u=c&dgps_uid=64cb5694e4b000cf748a30c2&dgps_t=cp_m

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# ### Importing the Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the dataset

# %%
data = pd.read_excel(r"C:\Users\ROHIT GREWAL\Desktop\Data Science Lovers\Videos\125. Project 9 - Sales Data Analysis\Start-Data-Analysis.xlsx")

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 258         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 259         NaN      10710  2022-12-29 00:00:00             Burgers
# 260         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 261         NaN      10712  2022-12-29 00:00:00               Fries
# 262         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# 0        Price    Quantity  Purchase Type  Payment Method             Manager
# 1         3.49  573.065903        Online        Gift Card    Tom      Jackson
# 2         2.95  745.762712        Online        Gift Card         Pablo Perez
# 3         4.99  200.400802      In-store        Gift Card       Joao    Silva
# 4        12.99  569.668976      In-store      Credit Card       Walter Muller
# ..         ...         ...            ...             ...                 ...
# 258       4.99  200.400802    Drive-thru        Gift Card       Walter Muller
# 259      12.99  754.426482    Drive-thru        Gift Card       Walter Muller
# 260       9.95  281.407035    Drive-thru        Gift Card       Walter Muller
# 261       3.49  630.372493    Drive-thru        Gift Card       Walter Muller
# 262       2.95  677.966102    Drive-thru        Gift Card       Walter Muller
#
#     Unnamed: 9
# 0         City
# 1       London
# 2       Madrid
# 3       Lisbon
# 4       Berlin
# ..         ...
# 258     Berlin
# 259     Berlin
# 260     Berlin
# 261     Berlin
# 262     Berlin
#
# [263 rows x 10 columns]

# %%
data.info()                                      # to show some basic informations about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  263 non-null    object
#  2   Unnamed: 2  263 non-null    object
#  3   Unnamed: 3  263 non-null    object
#  4   Unnamed: 4  263 non-null    object
#  5   Unnamed: 5  263 non-null    object
#  6   Unnamed: 6  263 non-null    object
#  7   Unnamed: 7  263 non-null    object
#  8   Unnamed: 8  263 non-null    object
#  9   Unnamed: 9  263 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.7+ KB

# %% [markdown]
# #### Drop Unwanted Column

# %%
data.drop(columns='Unnamed: 0', inplace=True)         # to drop the column from the dataframe

# %%
data.head()                                           # to show top 5 records of the dataframe
# Out:
#   Unnamed: 1           Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0   Order ID                 Date        Product      Price    Quantity
# 1      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 2      10453  2022-11-07 00:00:00      Beverages       2.95  745.762712
# 3      10454  2022-11-07 00:00:00  Sides & Other       4.99  200.400802
# 4      10455  2022-11-08 00:00:00        Burgers      12.99  569.668976
#
#       Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method             Manager       City
# 1        Online        Gift Card    Tom      Jackson     London
# 2        Online        Gift Card         Pablo Perez     Madrid
# 3      In-store        Gift Card       Joao    Silva     Lisbon
# 4      In-store      Credit Card       Walter Muller     Berlin

# %% [markdown]
# #### Changing the columns names

# %%
data.loc[0]                               # using the loc function to show Ist row values
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: object

# %%
data.columns                              # to show all the column names
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data.columns = data.loc[0]                # changing all the column names

# %%
data.head()
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 0  Order ID                 Date        Product  Price    Quantity
# 1     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00      Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00  Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00        Burgers  12.99  569.668976
#
# 0  Purchase Type  Payment Method             Manager    City
# 0  Purchase Type  Payment Method             Manager    City
# 1        Online        Gift Card    Tom      Jackson  London
# 2        Online        Gift Card         Pablo Perez  Madrid
# 3      In-store        Gift Card       Joao    Silva  Lisbon
# 4      In-store      Credit Card       Walter Muller  Berlin

# %% [markdown]
# #### Drop the unwanted Ist row

# %%
data.drop(0, inplace=True)                     # to delete the first row from the dataframe

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 258    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 259    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 260    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 261    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 262    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method             Manager    City
# 1         Online       Gift Card    Tom      Jackson  London
# 2         Online       Gift Card         Pablo Perez  Madrid
# 3       In-store       Gift Card       Joao    Silva  Lisbon
# 4       In-store     Credit Card       Walter Muller  Berlin
# 5       In-store     Credit Card       Walter Muller  Berlin
# ..            ...            ...                 ...     ...
# 258   Drive-thru       Gift Card       Walter Muller  Berlin
# 259   Drive-thru       Gift Card       Walter Muller  Berlin
# 260   Drive-thru       Gift Card       Walter Muller  Berlin
# 261   Drive-thru       Gift Card       Walter Muller  Berlin
# 262   Drive-thru       Gift Card       Walter Muller  Berlin
#
# [262 rows x 9 columns]

# %%
data.info()                               # to show some basic informations about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 1 to 262
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        262 non-null    object
#  1   Date            262 non-null    object
#  2   Product         262 non-null    object
#  3   Price           262 non-null    object
#  4   Quantity        262 non-null    object
#  5   Purchase Type   262 non-null    object
#  6   Payment Method  262 non-null    object
#  7   Manager         262 non-null    object
#  8   City            262 non-null    object
# dtypes: object(9)
# memory usage: 18.6+ KB

# %% [markdown]
# #### Consider the Manager column

# %%
data.head()
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card    Tom      Jackson  London
# 2       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store       Gift Card       Joao    Silva  Lisbon
# 4     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Walter Muller  Berlin

# %%
data.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 258         Walter Muller
# 259         Walter Muller
# 260         Walter Muller
# 261         Walter Muller
# 262         Walter Muller
# Name: Manager, Length: 262, dtype: object

# %%
data.Manager.unique()                     # to show all the unique values of the column
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()                      # to show count of unique values present in the column
# Out:
# 14

# %%
data['Manager'] = data['Manager'].str.strip().str.replace(r'\s+', ' ', regex=True)   # to remove extra spaces in names

# %%
data.head(20)
# Out:
# 0  Order ID                 Date             Product  Price    Quantity  \
# 1     10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5     10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6     10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7     10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 8     10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 9     10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 10    10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 11    10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 12    10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# 13    10464  2022-11-09 00:00:00       Sides & Other   4.99  200.400802
# 14    10465  2022-11-10 00:00:00             Burgers  12.99  554.272517
# 15    10466  2022-11-10 00:00:00  Chicken Sandwiches   9.95  201.005025
# 16    10467  2022-11-10 00:00:00               Fries   3.49  573.065903
# 17    10468  2022-11-10 00:00:00           Beverages   2.95  677.966102
# 18    10468  2022-11-10 00:00:00           Beverages   2.95  677.966102
# 19    10470  2022-11-11 00:00:00             Burgers  12.99  554.272517
# 20    10471  2022-11-11 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0  Purchase Type Payment Method        Manager    City
# 1        Online       Gift Card    Tom Jackson  London
# 2        Online       Gift Card    Pablo Perez  Madrid
# 3      In-store       Gift Card     Joao Silva  Lisbon
# 4      In-store     Credit Card  Walter Muller  Berlin
# 5      In-store     Credit Card  Walter Muller  Berlin
# 6      In-store     Credit Card     Remy Monet   Paris
# 7      In-store     Credit Card     Remy Monet   Paris
# 8      In-store     Credit Card  Walter Muller  Berlin
# 9      In-store     Credit Card     Remy Monet   Paris
# 10     In-store     Credit Card     Remy Monet   Paris
# 11     In-store     Credit Card     Remy Monet   Paris
# 12     In-store     Credit Card     Remy Monet   Paris
# 13     In-store     Credit Card     Remy Monet   Paris
# 14     In-store     Credit Card    Pablo Perez  Madrid
# 15     In-store     Credit Card    Pablo Perez  Madrid
# 16     In-store     Credit Card    Pablo Perez  Madrid
# 17     In-store     Credit Card    Pablo Perez  Madrid
# 18     In-store     Credit Card    Pablo Perez  Madrid
# 19     In-store     Credit Card    Pablo Perez  Madrid
# 20     In-store     Credit Card    Pablo Perez  Madrid

# %%
data['Manager'].unique()             # to show all the unique values of the column
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data['Manager'].nunique()             # to show count of unique values present in the column
# Out:
# 5

# %% [markdown]
# #### Removing the duplicate records

# %%
data.head()                     # to show top 5 records of the dataframe
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method        Manager    City
# 1       Online       Gift Card    Tom Jackson  London
# 2       Online       Gift Card    Pablo Perez  Madrid
# 3     In-store       Gift Card     Joao Silva  Lisbon
# 4     In-store     Credit Card  Walter Muller  Berlin
# 5     In-store     Credit Card  Walter Muller  Berlin

# %%
data.describe()                            # to show some summary about the columns
# Out:
# 0       Order ID                 Date Product   Price    Quantity  \
# count        262                  262     262  262.00  262.000000
# unique       254                   53       5   10.00   29.000000
# top        10539  2022-11-24 00:00:00   Fries    3.49  200.400802
# freq           2                    8      53   52.00   51.000000
#
# 0      Purchase Type Payment Method     Manager    City
# count            262            262         262     262
# unique             3              3           5       5
# top          Online     Credit Card  Joao Silva  Lisbon
# freq             107            128          78      78

# %%
data[data.duplicated()]                    # to show all the duplicate records
# Out:
# 0   Order ID                 Date        Product Price    Quantity  \
# 7      10457  2022-11-08 00:00:00          Fries  3.49  573.065903
# 18     10468  2022-11-10 00:00:00      Beverages  2.95  677.966102
# 136    10537  2022-11-24 00:00:00          Fries  3.49  630.372493
# 137    10538  2022-11-24 00:00:00      Beverages  2.95  745.762712
# 138    10539  2022-11-24 00:00:00  Sides & Other  4.99  200.400802
#
# 0   Purchase Type Payment Method      Manager    City
# 7       In-store     Credit Card   Remy Monet   Paris
# 18      In-store     Credit Card  Pablo Perez  Madrid
# 136   Drive-thru     Credit Card  Pablo Perez  Madrid
# 137   Drive-thru     Credit Card  Pablo Perez  Madrid
# 138   Drive-thru     Credit Card  Pablo Perez  Madrid

# %%
data.drop_duplicates(inplace=True)         # to remove the duplicate records

# %%
data[data.duplicated()]                    # to check the duplicate records
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.describe()                            # to show some summary about the columns
# Out:
# 0       Order ID                 Date  Product   Price    Quantity  \
# count        257                  257      257  257.00  257.000000
# unique       254                   53        5   10.00   29.000000
# top        10485  2022-11-13 00:00:00  Burgers   12.99  200.400802
# freq           2                    7       53   52.00   50.000000
#
# 0      Purchase Type Payment Method     Manager    City
# count            257            257         257     257
# unique             3              3           5       5
# top          Online     Credit Card  Joao Silva  Lisbon
# freq             107            123          78      78

# %%
data[data['Order ID'].duplicated()]        # to check the duplicate records in a column
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 66    10483  2022-11-13 00:00:00      Beverages   2.95  677.966102
# 67    10484  2022-11-13 00:00:00  Sides & Other   4.99  200.400802
# 68    10485  2022-11-14 00:00:00        Burgers  12.99    523.4796
#
# 0  Purchase Type Payment Method     Manager    City
# 66     In-store     Credit Card  Joao Silva  Lisbon
# 67     In-store     Credit Card  Joao Silva  Lisbon
# 68     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'] == 10483]            # using filtering to show some records
# Out:
# 0  Order ID                 Date    Product  Price    Quantity Purchase Type  \
# 32    10483  2022-11-13 00:00:00  Beverages  33.22  677.966102     In-store
# 66    10483  2022-11-13 00:00:00  Beverages   2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 32    Credit Card  Joao Silva  Lisbon
# 66    Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'] == 10484]            # using filtering to show some records
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 33    10484  2022-11-13 00:00:00  Sides & Other  21.44  200.400802
# 67    10484  2022-11-13 00:00:00  Sides & Other   4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 33     In-store     Credit Card  Joao Silva  Lisbon
# 67     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'] == 10485]           # using filtering to show some records
# Out:
# 0  Order ID                 Date  Product  Price  Quantity Purchase Type  \
# 34    10485  2022-11-14 00:00:00  Burgers  27.99  523.4796     In-store
# 68    10485  2022-11-14 00:00:00  Burgers  12.99  523.4796     In-store
#
# 0  Payment Method     Manager    City
# 34    Credit Card  Joao Silva  Lisbon
# 68    Credit Card  Joao Silva  Lisbon

# %%
data.drop(32, inplace=True)               # to remove any row with the index number

# %%
data[data['Order ID'] == 10483]
# Out:
# 0  Order ID                 Date    Product Price    Quantity Purchase Type  \
# 66    10483  2022-11-13 00:00:00  Beverages  2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 66    Credit Card  Joao Silva  Lisbon

# %%
data.drop([33, 34], inplace=True)         # to remove one or more rows with the index numbers

# %%
data[data['Order ID'] == 10484]
# Out:
# 0  Order ID                 Date        Product Price    Quantity  \
# 67    10484  2022-11-13 00:00:00  Sides & Other  4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 67     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'] == 10485]
# Out:
# 0  Order ID                 Date  Product  Price  Quantity Purchase Type  \
# 68    10485  2022-11-14 00:00:00  Burgers  12.99  523.4796     In-store
#
# 0  Payment Method     Manager    City
# 68    Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'].duplicated()]             # to check the duplicate records in a column
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 258    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 259    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 260    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 261    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 262    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method        Manager    City
# 1         Online       Gift Card    Tom Jackson  London
# 2         Online       Gift Card    Pablo Perez  Madrid
# 3       In-store       Gift Card     Joao Silva  Lisbon
# 4       In-store     Credit Card  Walter Muller  Berlin
# 5       In-store     Credit Card  Walter Muller  Berlin
# ..            ...            ...            ...     ...
# 258   Drive-thru       Gift Card  Walter Muller  Berlin
# 259   Drive-thru       Gift Card  Walter Muller  Berlin
# 260   Drive-thru       Gift Card  Walter Muller  Berlin
# 261   Drive-thru       Gift Card  Walter Muller  Berlin
# 262   Drive-thru       Gift Card  Walter Muller  Berlin
#
# [254 rows x 9 columns]

# %% [markdown]
# #### Converting the datatype of columns

# %%
data.info()                               # to get some basic info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 1 to 262
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 19.8+ KB

# %%
data.Quantity = data.Quantity.astype(float)  # to change the datatype of a column

# %%
data.info()                                  # to get some basic info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 1 to 262
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 19.8+ KB

# %%
data.Quantity = data.Quantity.round()              # to round-off the values of a column

# %%
data.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 258    200.0
# 259    754.0
# 260    281.0
# 261    630.0
# 262    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
data.Quantity = data.Quantity.astype(int)             # to change the datatype of a column

# %%
data['Quantity']
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 258    200
# 259    754
# 260    281
# 261    630
# 262    678
# Name: Quantity, Length: 254, dtype: int32

# %%
data['Order ID'] = data['Order ID'].astype(int)        # to change the datatype of a column
data['Price'] = data['Price'].astype(float)            # to change the datatype of a column

# %%
data.info()                                       # to get some basic info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 1 to 262
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int32
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), int32(2), object(6)
# memory usage: 17.9+ KB

# %%
data.Date = pd.to_datetime(data.Date)          # to convert the datatype into datetime format

# %%
data.Date.dtype                                # to check the datatype of any column
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 1 to 262
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int32
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int32(2), object(5)
# memory usage: 17.9+ KB

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# 1        Gift Card    Tom Jackson  London
# 2        Gift Card    Pablo Perez  Madrid
# 3        Gift Card     Joao Silva  Lisbon
# 4      Credit Card  Walter Muller  Berlin
# 5      Credit Card  Walter Muller  Berlin
# ..             ...            ...     ...
# 258      Gift Card  Walter Muller  Berlin
# 259      Gift Card  Walter Muller  Berlin
# 260      Gift Card  Walter Muller  Berlin
# 261      Gift Card  Walter Muller  Berlin
# 262      Gift Card  Walter Muller  Berlin
#
# [254 rows x 9 columns]

# %% [markdown]
# ----------

# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# #### Q.1) Most Preferred Payment Method ?

# %%
data.head()                       # to show top 5 records of the dataframe
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Payment Method'].unique()                       # to show the unique values of a column
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].nunique()                      # to show the count of unique values in a column
# Out:
# 3

# %%
data['Payment Method'].value_counts()                 # to show the unique values of a column with their counts
# Out:
#  Credit Card    120
#  Cash            76
#  Gift Card       58
# Name: Payment Method, dtype: int64

# %%
data['Payment Method'].value_counts(normalize=True)*100    # to get the result in percentage
# Out:
#  Credit Card    47.244094
#  Cash           29.921260
#  Gift Card      22.834646
# Name: Payment Method, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar') ;   # to draw the bar graph

# %% [markdown]
# #### Q.2) Most Selling Product ?
# - By Quantity
# - By Revenue

# %% [markdown]
# #### By Quantity

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data.groupby('Product')['Quantity'].sum()            # to make the group of unique values of a column
# Out:
# Product
# Beverages             34988
# Burgers               29018
# Chicken Sandwiches    11133
# Fries                 32023
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)   # to sort the result
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
most_quantity = data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
type(most_quantity)                   # to the type of the variable
# Out:
# pandas.core.series.Series

# %%
most_quantity = most_quantity.reset_index()     # To convert the index of a Series into a column to form a DataFrame
most_quantity
# Out:
#               Product  Quantity
# 0           Beverages     34988
# 1               Fries     32023
# 2             Burgers     29018
# 3  Chicken Sandwiches     11133
# 4       Sides & Other      9800

# %%
type(most_quantity)                   # to the type of the variable
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize = (9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'], color = ['red', 'black', 'green', 'yellow', 'cyan'], width=0.4)
plt.title("Most Selling Product - By Quantity")              
plt.xlabel("Product")
plt.ylabel("Quantity");

# %% [markdown]
# #### By Revenue

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Revenue'] = data['Price'] * data['Quantity']       # to create a new column 'Revenue'

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# 1        Gift Card    Tom Jackson  London  1999.77
# 2        Gift Card    Pablo Perez  Madrid  2200.70
# 3        Gift Card     Joao Silva  Lisbon   998.00
# 4      Credit Card  Walter Muller  Berlin  7404.30
# 5      Credit Card  Walter Muller  Berlin  1999.95
# ..             ...            ...     ...      ...
# 258      Gift Card  Walter Muller  Berlin   998.00
# 259      Gift Card  Walter Muller  Berlin  9794.46
# 260      Gift Card  Walter Muller  Berlin  2795.95
# 261      Gift Card  Walter Muller  Berlin  2198.70
# 262      Gift Card  Walter Muller  Berlin  2000.10
#
# [254 rows x 10 columns]

# %%
data.groupby('Product')['Revenue'].sum().sort_values(ascending = False) # to make the group of unique values of a column
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = data.groupby('Product')['Revenue'].sum().sort_values(ascending = False)
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = most_revnue.reset_index()         # To convert the index of a Series into a column to form a DataFrame
most_revenue
# Out:
#    index             Product    Revenue
# 0      0             Burgers  376943.82
# 1      1               Fries  125626.57
# 2      2  Chicken Sandwiches  114612.45
# 3      3           Beverages  103214.60
# 4      4       Sides & Other   48902.00

# %%
plt.figure(figsize=(9, 4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'], color = ['green', 'red', 'black', 'yellow', 'cyan'], width = 0.3);
plt.title("Most Selling Product - By Revenue")       # setting the title       
plt.xlabel("Product")                                # setting the x-axis label
plt.ylabel("Revenue");                               # setting the y-axis label

# %% [markdown]
# #### Q.3) Which city had maximum revenue
# ##### or
# ##### Which Manager earned maximum revenue

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# 1        Gift Card    Tom Jackson  London  1999.77
# 2        Gift Card    Pablo Perez  Madrid  2200.70
# 3        Gift Card     Joao Silva  Lisbon   998.00
# 4      Credit Card  Walter Muller  Berlin  7404.30
# 5      Credit Card  Walter Muller  Berlin  1999.95
# ..             ...            ...     ...      ...
# 258      Gift Card  Walter Muller  Berlin   998.00
# 259      Gift Card  Walter Muller  Berlin  9794.46
# 260      Gift Card  Walter Muller  Berlin  2795.95
# 261      Gift Card  Walter Muller  Berlin  2198.70
# 262      Gift Card  Walter Muller  Berlin  2000.10
#
# [254 rows x 10 columns]

# %%
data.City.unique()                       # to check the unique values of the column 'City'
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.City.nunique()                      # to check the count of unique values of the column 'City'
# Out:
# 5

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)   # using groupby on 'City' & 'Revenue' column
# Out:
# City
# Lisbon    241635.49
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %%
data.Manager.nunique()                   # to check the count of unique values of the column 'Manager'
# Out:
# 5

# %%
data.Manager.unique()                   # to check the unique values of the column 'Manager'
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)   # using groupby on 'Manager' & 'Revenue' column
# Out:
# Manager
# Joao Silva       241635.49
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# #### Q.4) Date wise revenue

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 1 to 262
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int32
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   Revenue         254 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int32(2), object(5)
# memory usage: 19.8+ KB

# %%
data.plot('Date', 'Revenue', color='red', linewidth=2, figsize=(9,4)) 
plt.title("Date wise Revenue")                        # setting the title
plt.xlabel("Date")                                    # setting the x-axis label
plt.ylabel("Revenue")                                 # setting the y-axis label
plt.show()

# %% [markdown]
# #### Q.5) Average Revenue

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Revenue'].mean()
# Out:
# 3028.737952755905

# %% [markdown]
# #### Q.6) Average Revenue of November & December month

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Month'] = data['Date'].dt.month              # creating a new column showing Month only

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# 1        Gift Card    Tom Jackson  London  1999.77     11
# 2        Gift Card    Pablo Perez  Madrid  2200.70     11
# 3        Gift Card     Joao Silva  Lisbon   998.00     11
# 4      Credit Card  Walter Muller  Berlin  7404.30     11
# 5      Credit Card  Walter Muller  Berlin  1999.95     11
# ..             ...            ...     ...      ...    ...
# 258      Gift Card  Walter Muller  Berlin   998.00     12
# 259      Gift Card  Walter Muller  Berlin  9794.46     12
# 260      Gift Card  Walter Muller  Berlin  2795.95     12
# 261      Gift Card  Walter Muller  Berlin  2198.70     12
# 262      Gift Card  Walter Muller  Berlin  2000.10     12
#
# [254 rows x 11 columns]

# %%
m11 = data[data['Month'] == 11]          # filtering the records with month '11'
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 114     10565 2022-11-30             Burgers  12.99       493       Online
# 115     10566 2022-11-30  Chicken Sandwiches   9.95       201       Online
# 116     10567 2022-11-30               Fries   3.49       630       Online
# 117     10568 2022-11-30           Beverages   2.95       678       Online
# 118     10569 2022-11-30       Sides & Other   4.99       200       Online
#
# 0   Payment Method        Manager    City  Revenue  Month
# 1        Gift Card    Tom Jackson  London  1999.77     11
# 2        Gift Card    Pablo Perez  Madrid  2200.70     11
# 3        Gift Card     Joao Silva  Lisbon   998.00     11
# 4      Credit Card  Walter Muller  Berlin  7404.30     11
# 5      Credit Card  Walter Muller  Berlin  1999.95     11
# ..             ...            ...     ...      ...    ...
# 114    Credit Card    Tom Jackson  London  6404.07     11
# 115    Credit Card    Tom Jackson  London  1999.95     11
# 116    Credit Card    Tom Jackson  London  2198.70     11
# 117    Credit Card    Tom Jackson  London  2000.10     11
# 118    Credit Card    Tom Jackson  London   998.00     11
#
# [113 rows x 11 columns]

# %%
m11.Revenue.mean()                           # to show the mean revenue
# Out:
# 2938.1869026548666

# %%
m12 = data[data.Month == 12]                  # filtering the records with month '12'
m12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 119     10570 2022-12-01             Burgers  12.99       493       Online
# 120     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 121     10572 2022-12-01               Fries   3.49       573       Online
# 122     10573 2022-12-01           Beverages   2.95       678       Online
# 123     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# 119    Credit Card    Tom Jackson  London  6404.07     12
# 120    Credit Card    Tom Jackson  London  1999.95     12
# 121    Credit Card     Remy Monet   Paris  1999.77     12
# 122    Credit Card     Remy Monet   Paris  2000.10     12
# 123    Credit Card     Remy Monet   Paris   998.00     12
# ..             ...            ...     ...      ...    ...
# 258      Gift Card  Walter Muller  Berlin   998.00     12
# 259      Gift Card  Walter Muller  Berlin  9794.46     12
# 260      Gift Card  Walter Muller  Berlin  2795.95     12
# 261      Gift Card  Walter Muller  Berlin  2198.70     12
# 262      Gift Card  Walter Muller  Berlin  2000.10     12
#
# [141 rows x 11 columns]

# %%
m12.Revenue.mean()                                  # to show the mean revenue
# Out:
# 3101.3072340425533

# %% [markdown]
# #### Q.7) Standard Deviation of Revenue and Quantity ?

# %%
data['Quantity'].std()
# Out:
# 214.97943096363838

# %%
data['Revenue'].std()
# Out:
# 2419.9325462715055

# %% [markdown]
# #### Q.8) Variance of Revenue and Quantity ?

# %%
data['Quantity'].var()
# Out:
# 46216.155737449764

# %%
data['Revenue'].var()
# Out:
# 5856073.528504092

# %% [markdown]
# #### Q.9) Is revenue increasing or decreasing over time?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
m11 = data[data['Month'] == 11]          # filtering the records with month '11'
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 114     10565 2022-11-30             Burgers  12.99       493       Online
# 115     10566 2022-11-30  Chicken Sandwiches   9.95       201       Online
# 116     10567 2022-11-30               Fries   3.49       630       Online
# 117     10568 2022-11-30           Beverages   2.95       678       Online
# 118     10569 2022-11-30       Sides & Other   4.99       200       Online
#
# 0   Payment Method        Manager    City  Revenue  Month
# 1        Gift Card    Tom Jackson  London  1999.77     11
# 2        Gift Card    Pablo Perez  Madrid  2200.70     11
# 3        Gift Card     Joao Silva  Lisbon   998.00     11
# 4      Credit Card  Walter Muller  Berlin  7404.30     11
# 5      Credit Card  Walter Muller  Berlin  1999.95     11
# ..             ...            ...     ...      ...    ...
# 114    Credit Card    Tom Jackson  London  6404.07     11
# 115    Credit Card    Tom Jackson  London  1999.95     11
# 116    Credit Card    Tom Jackson  London  2198.70     11
# 117    Credit Card    Tom Jackson  London  2000.10     11
# 118    Credit Card    Tom Jackson  London   998.00     11
#
# [113 rows x 11 columns]

# %%
m11['Revenue'].sum()
# Out:
# 332015.11999999994

# %%
m12 = data[data.Month == 12]                  # filtering the records with month '12'
m12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 119     10570 2022-12-01             Burgers  12.99       493       Online
# 120     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 121     10572 2022-12-01               Fries   3.49       573       Online
# 122     10573 2022-12-01           Beverages   2.95       678       Online
# 123     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 258     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 259     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 260     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 261     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 262     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# 119    Credit Card    Tom Jackson  London  6404.07     12
# 120    Credit Card    Tom Jackson  London  1999.95     12
# 121    Credit Card     Remy Monet   Paris  1999.77     12
# 122    Credit Card     Remy Monet   Paris  2000.10     12
# 123    Credit Card     Remy Monet   Paris   998.00     12
# ..             ...            ...     ...      ...    ...
# 258      Gift Card  Walter Muller  Berlin   998.00     12
# 259      Gift Card  Walter Muller  Berlin  9794.46     12
# 260      Gift Card  Walter Muller  Berlin  2795.95     12
# 261      Gift Card  Walter Muller  Berlin  2198.70     12
# 262      Gift Card  Walter Muller  Berlin  2000.10     12
#
# [141 rows x 11 columns]

# %%
m12.Revenue.sum()
# Out:
# 437284.32

# %% [markdown]
# #### Q.10) Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
data.groupby('Product')['Quantity', 'Revenue'].agg({'Quantity':'mean', 'Revenue':'mean'})  # using agg() with groupby()
# Out:
# C:\Users\ROHIT GREWAL\AppData\Local\Temp\ipykernel_21044\557679802.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Product')['Quantity', 'Revenue'].agg({'Quantity':'mean', 'Revenue':'mean'})  # using agg() with groupby()
# 0                     Quantity      Revenue
# Product
# Beverages           699.760000  2064.292000
# Burgers             558.038462  7248.919615
# Chicken Sandwiches  214.096154  2204.085577
# Fries               627.901961  2463.266078
# Sides & Other       200.000000   998.000000

# %% [markdown]
# --------------

# %% [markdown]
# --------------

# %% [markdown]
# --------------

# %% [markdown]
# ###### by - Rohit Grewal
# (Senior Data Analyst)
#
# (Learning Machine Learning)
